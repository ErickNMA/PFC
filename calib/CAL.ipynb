# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
# Configurações de plot:
plt.style.use([
    'grid',
    'retro'
])
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (12, 8)

# %%
J1 = np.array([
    [2598, 2448, 2321, 2186, 2022, 1904, 1795, 1661, 1555, 1448, 1326, 1207, 1093, 984],
    [-160.9, -134.1, -110.3, -84.2, -54.1, -31.5, -10.5, 14.9, 36.2, 56.1, 80.5, 103.7, 125.8, 148.2]
])

xvals = np.linspace(J1[0][0], J1[0][-1], 100)
p = np.polyfit(J1[0], J1[1], 1)
yvals = np.polyval(p, xvals)

plt.figure()
plt.title('Junta 1')
plt.plot(xvals, yvals, color='C2', linestyle='dashed', label=f'$y_1 = {round(p[0],4)}x + {round(p[1],4)}$')
plt.scatter(J1[0], J1[1], color='C0', linewidths=5)
plt.ylabel('Ângulo [°]')
plt.xlabel('ADC (bits)')
plt.legend()
plt.savefig('j1cal.eps', dpi=600, transparent=True, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
J2 = np.array([
    [878, 989, 1092, 1164, 1247, 1309, 1355, 1393, 1434, 1494],
    [26.2, 2.6, -18.3, -33.5, -44.1, -55.9, -64.9, -72.2, -79.8, -90.4]
])

xvals = np.linspace(J2[0][0], J2[0][-1], 100)
p = np.polyfit(J2[0], J2[1], 1)
yvals = np.polyval(p, xvals)

plt.figure()
plt.title('Junta 2')
plt.plot(xvals, yvals, color='C2', linestyle='dashed', label=f'$y_2 = {round(p[0],4)}x + {round(p[1],4)}$')
plt.scatter(J2[0], J2[1], color='C0', linewidths=5)
plt.ylabel('Ângulo [°]')
plt.xlabel('ADC (bits)')
plt.legend()
plt.savefig('j2cal.eps', dpi=600, transparent=True, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
J3 = np.array([
    [1049, 1103, 1203, 1326, 1413, 1503, 1614, 1720],
    [1.2, -10.5, -31.5, -56.9, -70.4, -88.4, -109.8, -131.8]
])

xvals = np.linspace(J3[0][0], J3[0][-1], 100)
p = np.polyfit(J3[0], J3[1], 1)
yvals = np.polyval(p, xvals)

plt.figure()
plt.title('Junta 3')
plt.plot(xvals, yvals, color='C2', linestyle='dashed', label=f'$y_3 = {round(p[0],4)}x + {round(p[1],4)}$')
plt.scatter(J3[0], J3[1], color='C0', linewidths=5)
plt.ylabel('Ângulo [°]')
plt.xlabel('ADC (bits)')
plt.legend()
plt.savefig('j3cal.eps', dpi=600, transparent=True, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
J4 = np.array([
    [2647, 2552, 2429, 2328, 2240, 2110, 2003, 1889, 1774, 1648, 1502, 1393, 1348],
    [-121.2, -102.5, -80.5, -62.4, -49.3, -21.5, -0.6, 20.5, 43.0, 65.3, 93.8, 112.5, 121.1]
])

xvals = np.linspace(J4[0][0], J4[0][-1], 100)
p = np.polyfit(J4[0], J4[1], 1)
yvals = np.polyval(p, xvals)

plt.figure()
plt.title('Junta 4')
plt.plot(xvals, yvals, color='C2', linestyle='dashed', label=f'$y_4 = {round(p[0],4)}x + {round(p[1],4)}$')
plt.scatter(J4[0], J4[1], color='C0', linewidths=5)
plt.ylabel('Ângulo [°]')
plt.xlabel('ADC (bits)')
plt.legend()
plt.savefig('j4cal.eps', dpi=600, transparent=True, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
J5a = np.array([
    [1162, 978, 886],
    [-153.6, -117.0, -98.9]
])
J5b = np.array([
    [2607, 2451, 2313, 2196, 2028, 1865, 1708, 1536, 1386],
    [-67.6, -37.5, -11.1, 9.2, 37.7, 66.6, 97.7, 134.3, 163.5]
])

xvals = np.linspace(J5a[0][-1], J5b[0][0], 100)
p1 = np.polyfit(J5a[0], J5a[1], 1)
yvals1 = np.polyval(p1, xvals)
p2 = np.polyfit(J5b[0], J5b[1], 1)
yvals2 = np.polyval(p2, xvals)

plt.figure()
plt.title('Junta 5')
plt.plot((1250, 1250), (yvals2[np.abs(xvals-1250).argmin():][0], yvals1[:np.abs(xvals-1250).argmin()][-1]), color='C5', linestyle='dotted')
plt.plot(xvals[:np.abs(xvals-1250).argmin()], yvals1[:np.abs(xvals-1250).argmin()], color='C2', linestyle='dashed', label=f'$y_5 = {round(p1[0],4)}x + {round(p1[1],4)}$')
plt.plot(xvals[np.abs(xvals-1250).argmin():], yvals2[np.abs(xvals-1250).argmin():], color='C4', linestyle='dashed', label=f'$y_5 = {round(p2[0],4)}x + {round(p2[1],4)}$')
plt.scatter(J5a[0], J5a[1], color='C0', linewidths=5)
plt.scatter(J5b[0], J5b[1], color='C1', linewidths=5)
plt.ylabel('Ângulo [°]')
plt.xlabel('ADC (bits)')
plt.legend()
plt.savefig('j5cal.eps', dpi=600, transparent=True, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
GRIPa = np.array([
    [1478, 1860, 2303, 2485, 2652],
    [83, 64, 42, 34, 30]
])
GRIPb = np.array([
    [934, 1049, 1176],
    [16, 10, 3]
])

xvals = np.linspace(GRIPb[0][0], GRIPa[0][-1], 100)
p1 = np.polyfit(GRIPa[0], GRIPa[1], 1)
yvals1 = np.polyval(p1, xvals)
p2 = np.polyfit(GRIPb[0], GRIPb[1], 1)
yvals2 = np.polyval(p2, xvals)

plt.figure()
plt.title('Garra')
plt.plot((1250, 1250), (yvals2[np.abs(xvals-1250).argmin():][0], yvals1[:np.abs(xvals-1250).argmin()][-1]), color='C5', linestyle='dotted')
plt.plot(xvals[np.abs(xvals-1250).argmin():], yvals1[np.abs(xvals-1250).argmin():], color='C4', linestyle='dashed', label=f'$y_6 = {round(p1[0],4)}x + {round(p1[1],4)}$')
plt.plot(xvals[:np.abs(xvals-1250).argmin()], yvals2[:np.abs(xvals-1250).argmin()], color='C2', linestyle='dashed', label=f'$y_6 = {round(p2[0],4)}x + {round(p2[1],4)}$')
plt.scatter(GRIPa[0], GRIPa[1], color='C1', linewidths=5)
plt.scatter(GRIPb[0], GRIPb[1], color='C0', linewidths=5)
plt.ylabel('Abertura [mm]')
plt.xlabel('ADC (bits)')
plt.legend()
plt.savefig('j6cal.eps', dpi=600, transparent=True, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
